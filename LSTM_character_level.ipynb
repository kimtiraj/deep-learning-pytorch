# %% [markdown]
# <a href="https://colab.research.google.com/github/kimtiraj/deep-learning-pytorch/blob/main/LSTM_character_level.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)

# %%
# !pip install Unidecode
# Out:
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 7.8MB/s
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.2.0

# %%
import torch
import torch.nn as nn
import string
import random
import sys
import unidecode
from torch.utils.tensorboard import SummaryWriter

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Get characters from string.printable
all_characters = string.printable
n_characters = len(all_characters)

# %%
# Read large text file (Note can be any text file: not limited to just names)
file = unidecode.unidecode(open("/content/names.txt").read())

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embed = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden, cell):
        out = self.embed(x)
        out, (hidden, cell) = self.lstm(out.unsqueeze(1), (hidden, cell))
        out = self.fc(out.reshape(out.shape[0], -1))
        return out, (hidden, cell)

    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        cell = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        return hidden, cell

# %%
class Generator:
    def __init__(self):
        self.chunk_len = 250
        self.num_epochs = 5000
        self.batch_size = 1
        self.print_every = 50
        self.hidden_size = 256
        self.num_layers = 2
        self.lr = 0.003

    def char_tensor(self, string):
        tensor = torch.zeros(len(string)).long()
        for c in range(len(string)):
            tensor[c] = all_characters.index(string[c])
        return tensor

    def get_random_batch(self):
        start_idx = random.randint(0, len(file) - self.chunk_len)
        end_idx = start_idx + self.chunk_len + 1
        text_str = file[start_idx:end_idx]
        text_input = torch.zeros(self.batch_size, self.chunk_len)
        text_target = torch.zeros(self.batch_size, self.chunk_len)

        for i in range(self.batch_size):
            text_input[i, :] = self.char_tensor(text_str[:-1])
            text_target[i, :] = self.char_tensor(text_str[1:])

        return text_input.long(), text_target.long()

    def generate(self, initial_str="A", predict_len=100, temperature=0.85):
        hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
        initial_input = self.char_tensor(initial_str)
        predicted = initial_str

        for p in range(len(initial_str) - 1):
            _, (hidden, cell) = self.rnn(
                initial_input[p].view(1).to(device), hidden, cell
            )

        last_char = initial_input[-1]

        for p in range(predict_len):
            output, (hidden, cell) = self.rnn(
                last_char.view(1).to(device), hidden, cell
            )
            output_dist = output.data.view(-1).div(temperature).exp()
            top_char = torch.multinomial(output_dist, 1)[0]
            predicted_char = all_characters[top_char]
            predicted += predicted_char
            last_char = self.char_tensor(predicted_char)

        return predicted

    # input_size, hidden_size, num_layers, output_size
    def train(self):
        self.rnn = RNN(
            n_characters, self.hidden_size, self.num_layers, n_characters
        ).to(device)

        optimizer = torch.optim.Adam(self.rnn.parameters(), lr=self.lr)
        criterion = nn.CrossEntropyLoss()
        writer = SummaryWriter(f"runs/names0")  # for tensorboard

        print("=> Starting training")

        for epoch in range(1, self.num_epochs + 1):
            inp, target = self.get_random_batch()
            hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)

            self.rnn.zero_grad()
            loss = 0
            inp = inp.to(device)
            target = target.to(device)

            for c in range(self.chunk_len):
                output, (hidden, cell) = self.rnn(inp[:, c], hidden, cell)
                loss += criterion(output, target[:, c])

            loss.backward()
            optimizer.step()
            loss = loss.item() / self.chunk_len

            if epoch % self.print_every == 0:
                print(f"Loss: {loss}")
                print(self.generate())

            writer.add_scalar("Training loss", loss, global_step=epoch)

# %%
gennames = Generator()
gennames.train()
# Out:
# => Starting training
# Loss: 2.335198486328125
# Alson
# Rinisse
# AnnTlen
# Canirila
# Eaillis
# Crtarer
# Kaxwden
# Makdn
# istie
# Altfes
# Jeran
# Erkonyy
# Kaledty
# Danla
# Loss: 2.38826123046875
# Adell
# Martthy
# Milre
# Lansth
# Almory
# Ladellla
# Rard
# Jurlie
# Malma
# Jamon
# Lillyn
# Waall
# Vandes
# Allitt
# Lerllo
#
# Loss: 2.0296644287109373
# A
# Hologieo
# Bannicon
# Dumon
# Etter
# Elick
# Reegann
# Caan
# Welle
# Chereritt
# Bris
# Sheert
# Jobence
# Lefis
# Callee
# C
# Loss: 2.079482177734375
# Abus
# Shenney
# Jacecky
# Logan
# Rbatlece
# Dalia
# Kyla
# Jeissah
# Rocpric
# Elistell
# Jael
# Ceallia
# Kamvely
# Hoseynce
# Loss: 1.8856839599609374
# Ana
# Herla
# Pannaya
# Rov
# Denga
# Aloris
# Herith
# Cattine
# Brellie
# Jen
# Raishy
# Tyaby
# Loris
# Jezer
# Jewish
# Kanliel
# Loss: 2.08375537109375
# Atti
# Donny
# Rovuy
# Agerley
# Ama
# Shallie
# Tarrie
# Isan
# Lay
# Delline
# Alman
# WenTiel
# Maylista
# Shannie
# Kayleon
# J
# Loss: 1.9584482421875
# Alial
# Shenardy
# Datane
# Ednon
# Esamlice
# Lany
# Sannisa
# Dane
# Glyn
# Nanton
# Clera
# vormis
# Shallina
# Andreron
# Ana
# Loss: 2.02939697265625
# Anne
# Jayonya
# Shaolyn
# Balell
# Katethie
# Yobyn
# Eamey
# Wayla
# Benny
# Jamasher
# Gerrielt
# Tauris
# Clinda
# Scakey
# L
# Loss: 1.6742666015625
# Alena
# Emel
# Bennell
# Darlen
# Joomon
# Jouer
# Carrold
# Donn
# Denny
# Euderell
# Charlan
# Muron
# Jessen
# Ary
# Kore
# Colr
# Loss: 1.8713990478515625
# Anta
# Aurie
# Kenny
# Ton
# Adel
# Zeana
# Chyd
# Dalusa
# Charla
# Alsha
# Deol
# Emore
# Contina
# Alaudia
# Cartha
# Colla
# Wyma
# Loss: 1.6574764404296876
# Antley
# Trena
# Edgan
# Paul
# Cadelan
# Carlail
# ever
# Maria
# Arnesta
# Dessia
# Twzie
# Janna
# Elled
# Dichakl
# Douber
# Qo
# Loss: 1.7256048583984376
# Ann
# Jeffery
# Trance
# Kalison
# Klauda
# Jason
# Killi
# Colky
# Aleona
# Clisa
# Joe
# Nica
# Lorrie
# Jamey
# Cari
# Waven
# Hen
# Loss: 1.6093919677734374
# Alpher
# Anie
# Nolan
# Rosie
# Habriela
# Kason
# Gadeline
# Marol
# Gred
# Nolany
# Ritha
# Alan
# Dea
# Suanda
# Hellis
# Madise
# Loss: 1.5686923828125
# Anita
# Elina
# Tamm
# Judert
# Karlen
# Julie
# Corric
# Sara
# Jaamine
# Kassie
# Shane
# Olivia
# Tayla
# Taud
# Delian
# Jackie
# Loss: 1.636114013671875
# Annelle
# Frankie
# Synhell
# Mollina
# Arlendel
# Rachola
# Dianna
# Dun
# Elorence
# Fernesta
# Tona
# Irron
# Hurgie
# Angia
# Loss: 1.5226466064453126
# Ana
# Vabiley
# Dax
# Mariah
# Calter
# Trance
# Rexia
# Grace
# Kendrad
# Jazey
# Shellin
# Joother
# Clara
# Denaya
# Moverlyn
#
# Loss: 1.7794229736328124
# Annis
# Sophia
# Angelynn
# Gracey
# Ricky
# Roger
# Dilma
# Marcine
# Kalley
# Vadel
# James
# Bristen
# Ravon
# Isarie
# Shella
# Loss: 1.3655498046875
# Alison
# Iderick
# Francy
# Karie
# Ashlyn
# Sharlyw
# Alica
# Diane
# Nikiline
# Marian
# Carrie
# Nelm
# Falen
# Gwendrett
# Br
# Loss: 1.3617489013671875
# Annia
# Sherry
# Rapantley
# Stephen
# Tovie
# Karlie
# Bett
# Varnie
# Eudie
# Jeane
# Kienne
# Matisha
# Saria
# Jane
# Terri
# G
# Loss: 1.4671962890625
# Aley
# Laelind
# Janol
# Mariel
# Carol
# Nena
# Lashin
# Loura
# Alfrey
# Herl
# Darriel
# Loret
# Naton
# Josey
# Sael
# Ewnolyn
#
# Loss: 1.4552227783203124
# Alene
# Jacqueline
# Marie
# Marion
# Kaitline
# Millie
# Mari
# Edra
# Vert
# Carolis
# Ruben
# Raver
# Nathanya
# Randra
# Nels
# Loss: 1.372380859375
# Anneth
# Julian
# Brekdie
# Don
# Glennie
# Annie
# Lue
# Michelie
# Sameva
# Andrew
# Blan
# Twandy
# Allie
# Calph
# Stonya
# Sha
# Loss: 1.26308251953125
# Annie
# Alexandra
# Scotta
# Fora
# Eresa
# Bravian
# Henry
# Michera
# Davis
# San
# Ren
# Gadel
# Winsley
# Elma
# Leathance
# Al
# Loss: 1.5513765869140625
# Arlie
# Ruley
# Dorothy
# Harold
# Lianah
# Nicharg
# Morgan
# Amil
# Asia
# Emma
# Gruckline
# Carla
# Marie
# Jeanette
# Vingin
# Loss: 1.470899169921875
# Anne
# Amand
# Coles
# Janie
# Ella
# Elaina
# Betha
# Bradby
# Bobby
# Bennie
# Gersly
# Viold
# Earl
# Asha
# Bersha
# Emuila
# Car
# Loss: 1.1213704833984375
# Arby
# Tracie
# Darriette
# Drewley
# Pedrick
# Elise
# Bernaldie
# Sarah
# Shary
# Allyssa
# Amiya
# Artin
# Tamya
# Alile
# Ant
# Loss: 1.2514830322265624
# Asha
# Alxie
# Drances
# Stacy
# Jakiyah
# Tamekiah
# Leigh
# Ricky
# Terestine
# Stephen
# Bilton
# Clevin
# Oliveit
# Amy
# She
# Loss: 1.243491455078125
# Anda
# Barbara
# Alissa
# Elizabeth
# Christin
# Paul
# Jakim
# Janet
# Payt
# Alichon
# Sharon
# Cales
# Gayden
# Kayla
# Kamero
# Loss: 1.4850433349609375
# Asta
# Arnestine
# Amy
# Aubrey
# Carolph
# Elizabeth
# Colby
# Shirley
# Corie
# Brooksie
# Carly
# Kristine
# Danna
# Lea
# Lar
# Loss: 1.4987322998046875
# Ashlin
# Brady
# Elizabeth
# Evin
# Abbie
# Colphlyn
# Ivan
# Oscie
# Marcy
# Hharlee
# Rosa
# Frarissa
# Maiden
# Kristina
# Jay
# Loss: 1.365578125
# Alza
# Autumn
# Eugen
# Alphonso
# Janet
# Jesse
# Martin
# Brenda
# Chris
# Terferd
# Vidkey
# Etta
# Anjomi
# Buel
# Brandon
# Da
# Loss: 1.1062821044921876
# Andy
# Glena
# Maurice
# Jayden
# Jyson
# Janie
# Pat
# Vanessa
# Jamie
# Lillie
# Nina
# Rulie
# Shelma
# Tessie
# Alan
# Bryant
# H
# Loss: 1.5488348388671875
# Arrie
# Chitha
# Kirstian
# Kenton
# Corine
# Kaleb
# Timothy
# Willista
# Pammie
# Ashancos
# Scotte
# Racheal
# Suelan
# Ange
# Loss: 1.268962890625
# Ala
# Joanna
# Ally
# Harold
# Ellaur
# Frankie
# Lee
# Isay
# Mary
# Maxton
# Lorene
# Morris
# Leogarus
# LakayMar
# Ottic
# Russ
# Loss: 1.2789378662109374
# Asley
# Angelia
# Annne
# Erok
# Wayne
# Alex
# Crill
# Lacie
# Levan
# Jerry
# Ludia
# Jason
# Junifer
# Jeffrey
# Gail
# Jamie
# Ja
# Loss: 1.4355289306640624
# Alla
# Erita
# Dexter
# Edd
# Elma
# Gabriella
# Marley
# Margaret
# Staci
# Reigh
# Willie
# Marcor
# Pat
# Doria
# Randall
# Aver
# Loss: 1.42913427734375
# Ales
# Ester
# Norine
# Losie
# Sterlind
# Rebecca
# Wendall
# Alexie
# Cyfor
# Allison
# Alexis
# Danielle
# Daryl
# Casiya
# Ed
# Loss: 1.1824593505859375
# Allie
# Celanda
# Leisha
# Alexia
# Alexandre
# Crystie
# Hudy
# Herschel
# Marsha
# Odis
# Meghan
# Tyler
# Virgle
# Zackeria
#
# Loss: 1.4066619873046875
# Alma
# Stephanie
# Tracy
# Harison
# Jared
# Jocelyn
# Jamer
# Kristy
# Katrina
# Nick
# Verdi
# rad
# Roody
# Samuel
# Skylar
# Br
# Loss: 1.293876220703125
# Adford
# Cornell
# Eliz
# Emmay
# Buster
# Camarette
# Kathryn
# Luslee
# Leroy
# Nole
# Non
# Odessie
# Winford
# Wilson
# Walte
# Loss: 1.331643310546875
# Alexander
# Brook
# Cecil
# Charlotte
# Exie
# Galey
# Harest
# Herthon
# Julian
# Juanita
# Kourtis
# Marie
# Meghan
# Justin
#
# Loss: 1.202177001953125
# Alda
# Charles
# Drick
# William
# Ted
# Trina
# Zanda
# Shanika
# Shondy
# Ricard
# Rolanso
# Adrian
# Charles
# Charlie
# Charl
# Loss: 1.4097078857421874
# Alena
# Carl
# Franklin
# Henry
# Jacquelyn
# Jameson
# Jamie
# Jacksoh
# Jacobey
# Jeannette
# Janie
# Kenny
# Kaya
# Kenneth
#
# Loss: 1.1500347900390624
# Alyson
# Annie
# Glen
# Eliza
# Holly
# Alizam
# Arthur
# Antonia
# Alicia
# Camille
# Carmen
# Charliya
# Catherine
# Caden
# Ho
# Loss: 1.219547607421875
# Ashle
# Latri
# Alana
# Ashley
# Braden
# Jonnie
# Eliza
# Jerretta
# Johnathany
# Jalen
# Justine
# Julian
# Kawleen
# Latiana
# Loss: 1.34571337890625
# Allison
# April
# Alma
# Randall
# Raven
# Daxton
# Eernest
# Fonnie
# Odell
# Eddie
# Chester
# Eugene
# Gorge
# Elaine
# Gerald
# Loss: 1.3443363037109375
# An
# Zettie
# Winnie
# Charlott
# Leigh
# Katie
# Kelsey
# Mamie
# Michael
# Molly
# Mark
# Johnathan
# Jolene
# Lukas
# Randy
# An
# Loss: 1.042154541015625
# Asher
# Carrie
# Curtis
# Gonroe
# Harold
# Hollie
# Juder
# Joanna
# Karlie
# Corey
# Stacey
# Shandra
# Tabitha
# Tora
# Tyler
#
# Loss: 1.1793133544921874
# Alissa
# Andra
# Cecil
# Cornelia
# Ciantha
# Duana
# Omario
# Lennie
# Timothy
# Sally
# Tiera
# Theresa
# Andrew
# Williana
# A
# Loss: 1.1828162841796874
# Alexander
# Annette
# Benjamin
# Andrew
# Andrew
# Bradford
# Charlie
# Cherita
# Chadwige
# Eli
# Evan
# Ginsie
# James
# Jenn
# Loss: 1.3800919189453125
# Aurela
# Clay
# Chelsey
# George
# Lake
# Laury
# Lakenzie
# Leland
# Lorraine
# Lucy
# Maria
# Mckenzie
# Ollie
# Velene
# Cori
#
# Loss: 1.276968017578125
# Aureline
# Ann
# Ashton
# Benjamin
# Chris
# Delma
# Frances
# Jack
# Marley
# Margaret
# Philip
# Ruslee
# Toby
# Sharon
# Treve
# Loss: 1.357009521484375
# Andria
# Alberta
# Britney
# Brandon
# Corin
# Carolina
# Delphine
# Eric
# Elmore
# Eric
# Harold
# Josy
# Maxwell
# Melva
# Nea
# Loss: 1.2865130615234375
# An
# Alisa
# Taura
# Vanessa
# Alton
# Alisandra
# Alice
# Bonita
# Carrie
# Jonnie
# Kinsley
# Katherine
# Jami
# Jerrell
# Ben
#
# Loss: 1.2299083251953125
# Adbie
# Alise
# Austin
# Ashleigh
# Alberta
# Ann
# Angela
# Bernice
# Cassie
# Davis
# Evelyn
# Jackie
# Joanna
# Jimmie
# Lynds
# Loss: 1.1341878662109375
# Alexander
# Bridgett
# Clayton
# Condrea
# Frank
# Mallon
# Maddel
# Noke
# Nancy
# Nolan
# Xavier
# Wade
# Ruthie
# Janet
# Irla
# Loss: 1.3609718017578125
# Artha
# Adriana
# Ariel
# Joyce
# Gary
# Jeannette
# Katherine
# Lelia
# Kaikey
# Marcella
# Nichard
# Mon
# Petsy
# Sadys
# Tyby
# Loss: 1.15154931640625
# Alicia
# Angelica
# Antione
# Illa
# Janice
# Jamiya
# Tina
# Lillie
# Terrence
# Wyatt
# Carley
# Kayley
# Juan
# Lashanda
# Tam
# Loss: 1.0798951416015625
# Alichie
# Cole
# Abigabeth
# Alicia
# Auther
# Desmonda
# Dianna
# Emily
# Emily
# Emma
# Eri
# Emmy
# Evelee
# Edward
# Bertha
# K
# Loss: 1.039857177734375
# Amana
# Annette
# Ellen
# Gabriel
# Leslie
# Hollie
# Imo
# Jake
# Jakree
# John
# Raylene
# Deandre
# Janie
# Jaylen
# Jordyn
# Ja
# Loss: 1.2358487548828125
# Aldon
# Cody
# Dalor
# Elisa
# Della
# Felicio
# Eleanor
# Jaylyn
# Kinson
# Kathleen
# Krio
# Mrevi
# Macie
# Moses
# Ross
# Sylve
# Loss: 1.1853153076171874
# Ariana
# Barry
# Alfrey
# Alexander
# Alisa
# Bethany
# Carlos
# Carper
# Christine
# Don
# Emmette
# Emary
# Elma
# Joseph
# Joh
# Loss: 1.1697236328125
# Alex
# Audrey
# Adrian
# Alton
# Adah
# Alva
# Bob
# Allene
# Antiogo
# Johnny
# Morgan
# Robin
# Tristan
# Woodie
# Winston
# Brit
# Loss: 1.270820556640625
# Alene
# Addie
# Verna
# Tyron
# Clifford
# Zoney
# Cleve
# Glenda
# Everette
# Freddy
# Gloria
# Irland
# Joann
# Jesse
# Joel
# Jo
# Loss: 1.0907803955078126
# Ashin
# Cheryl
# Anna
# Bernice
# Corine
# Kyla
# Louie
# Maggie
# Max
# Tommie
# Willia
# Vernice
# Scott
# Christina
# Dannie
# E
# Loss: 1.2534649658203125
# Adrien
# Donovan
# Kurtis
# Joy
# John
# Melander
# Maudia
# Marlene
# Mose
# Ollie
# Nathan
# Tristine
# Willie
# Alexandra
# An
# Loss: 1.0738662109375
# Andrea
# Aylee
# Ashton
# Alford
# Aaron
# Bernie
# Brenton
# Angeline
# Billy
# Billy
# Dave
# Shelby
# Waylon
# Aubrey
# Ashly
#
# Loss: 1.498710693359375
# Alfred
# Brody
# Carrie
# Denalus
# Donald
# Judy
# Paggie
# Philip
# Don
# Devin
# Jerra
# Paula
# Jerrie
# Trista
# Janet
# Jazmy
# Loss: 1.0562054443359374
# Anita
# Averi
# Bobbie
# Anna
# Alisa
# Alvin
# Addie
# Charles
# Cassadia
# Chamenter
# Donnie
# Dorine
# Dora
# Jacky
# Josephi
# Loss: 1.247896484375
# Aphi
# Destiny
# Allyson
# Alvin
# Tamara
# Tamara
# Tony
# William
# William
# Demmika
# Rosalind
# Dantel
# Ennis
# Harrison
#
# Loss: 1.234322265625
# Artis
# Claudine
# Dana
# Darius
# Denise
# Emery
# Rashawn
# Sherrie
# Santel
# Suzanne
# Tom
# Brylin
# Colly
# Della
# Deanna
#
# Loss: 1.1301680908203124
# Alyson
# Adell
# Stacy
# Benny
# Baylon
# Bryant
# Cecerius
# Conrad
# Derocca
# Craig
# Dewey
# Elphus
# Kayden
# Kelly
# Marcus
# Loss: 1.139130859375
# Annis
# Antrya
# Geie
# Hal
# Jamie
# Maggie
# Margueritia
# Marina
# Minie
# Michaela
# Kyle
# Maggie
# Martin
# Melanie
# Matil
# Loss: 1.03263916015625
# Audison
# Ansley
# Charles
# Cameron
# Celeste
# Coleman
# Devonte
# Madeline
# Ernest
# Artis
# Kristopher
# Jamie
# Nancy
# P
# Loss: 1.050438720703125
# Angalyn
# Bethany
# Cintha
# Tommy
# Chandra
# Karley
# Kayla
# Kalie
# Kristus
# Tannie
# Terreli
# Nichole
# Wandi
# Eroki
# Ha
# Loss: 1.122212890625
# Alma
# Annie
# Ariel
# Alphus
# Cayden
# Cameron
# Donald
# Christine
# Grace
# Lianne
# Martha
# Melody
# Marlon
# Stacie
# Stac
# Loss: 1.0630076904296875
# Athel
# Andrew
# Bailee
# Gregory
# Brail
# Bryan
# Berry
# Peter
# Lucious
# Ben
# Darryl
# Delores
# Elis
# Helin
# Hollie
# Hell
# Loss: 1.0109037475585938
# Abbie
# Byron
# Chance
# Clayton
# Charlie
# Cheyanne
# Cassie
# Vicky
# Pauline
# Denise
# Coretta
# Dennis
# Nelsie
# Nellie
#
# Loss: 1.4739248046875
# Amariah
# Gavin
# Kenyah
# Stella
# Karson
# Treya
# Anita
# Christina
# Della
# Dorothy
# Bridgette
# Harriett
# Jaquella
# Ja
# Loss: 1.0891787109375
# Alawson
# Anthony
# Brennan
# Brondon
# Bradford
# Carton
# Demetrius
# Darrell
# Emerson
# Gerald
# Martin
# Marc
# Mary
# Iss
# Loss: 0.987432373046875
# Ayla
# Bryley
# Kadence
# Karlene
# Kalen
# Kathleen
# Kayla
# Kristian
# Lukah
# Marke
# Michelle
# Melanie
# Natasha
# Quincy
# Loss: 1.031410888671875
# Allee
# Allison
# Boyd
# Charlton
# Christophe
# Dominic
# Kendra
# Kenley
# Lionad
# Leo
# Michelle
# Robin
# Serenita
# Loren
# Loss: 1.070345458984375
# Anita
# Angeline
# Annabelle
# Bill
# Anna
# Heyle
# Horace
# Jade
# Josie
# Jannie
# Kayla
# Linda
# Martha
# Marisa
# Mary
# Land
# Loss: 1.4192677001953125
# Ann
# Carlta
# Dale
# Jona
# Lana
# Mavis
# Jennifer
# Kimberly
# Kelsi
# Kadence
# Kathryn
# Letha
# Paula
# Vera
# Belinda
# Dona
# Loss: 1.0974205322265624
# Allen
# Dina
# Judith
# Lucile
# Lillian
# Mildred
# Ralph
# Arthur
# Billie
# Callie
# Dejuan
# Hula
# Judder
# Lexis
# Lorene
# M
# Loss: 1.20472412109375
# Annetta
# Annisha
# Vernice
# Vanessa
# Bryanna
# Caroline
# Carey
# Collina
# Karlie
# Mary
# Michele
# Marla
# Patisha
# Shar
# Loss: 1.1099410400390626
# Addie
# Jimmie
# Beatrice
# Colleen
# Donna
# Patsy
# Kylett
# Mary
# Percy
# Rose
# Winley
# Antonia
# Dallas
# Homer
# Henry
# He
# Loss: 1.035157958984375
# Ala
# Anna
# Alvin
# Alfonso
# Arlena
# April
# Cari
# Catelyn
# Carl
# Curtis
# Sebastian
# Stacie
# Tannie
# Autumn
# Bessie
# Be
# Loss: 1.0951973876953125
# Alexandr
# Clifford
# Cleody
# Gregian
# June
# Jaxon
# Marshall
# Levi
# Leo
# Rodie
# Rodnis
# Reuben
# Ceyton
# Gene
# Jeremia
# Loss: 1.100724365234375
# Andy
# Stephen
# Walter
# Amari
# Henry
# Chase
# Courtney
# Darrell
# Sarah
# Alpa
# Patrick
# Virginia
# Candice
# Catherine
#
# Loss: 1.306883056640625
# Anarcus
# Antoine
# Ashlynn
# Alfonso
# Allyssa
# Janis
# Cassall
# Betsy
# Karla
# Katie
# Dannell
# Killi
# Larence
# Patrici
# Loss: 0.9878645629882813
# Annie
# Angela
# Betsy
# Laverne
# Logan
# Bertie
# Cynthia
# Dollie
# Florine
# Irene
# Lenuel
# Lou
# Mariana
# Michele
# Pauli
# Loss: 1.21110498046875
# Aubrey
# Calvin
# Dian
# Emilion
# Edmine
# Erik
# Earlie
# Edward
# Graham
# Haley
# Jonathan
# Lowell
# Palson
# Williom
# Ronn
# Loss: 1.039576904296875
# Auth
# Clint
# Holly
# Jacqueline
# Jada
# Kaye
# Leslie
# Lauren
# Ema
# Maria
# Macey
# Trina
# Victoria
# Adrian
# Cassandra
# H
# Loss: 1.11856689453125
# Angela
# Brie
# Cara
# Ciara
# Caitlin
# Claire
# Debby
# Elika
# Frankie
# Glenda
# Sarah
# Sarah
# Sydney
# Sophie
# Sonda
# Tamy
# Loss: 1.1495401611328124
# Anita
# Autumn
# Alycia
# Audie
# Aliyah
# Anna
# Ashlyn
# Ann
# Bertha
# Kendra
# Loretta
# Allie
# Jessica
# Karley
# Lilia
# Mad
# Loss: 0.8741271362304688
# Aleja
# Alesia
# Shellie
# Connie
# Elsie
# Fay
# Grace
# Hali
# Holly
# April
# Jacqueline
# Laura
# Alexandra
# Abbie
# Cassand
# Loss: 0.9376171875
# Andrew
# Janis
# Acton
# Calvin
# Cole
# Dallas
# Elison
# Irlkn
# John
# Joshua
# Ronald
# Kerry
# Victor
# Willard
# Donald
# Ric
# Loss: 1.036280517578125
# Amond
# Bradlen
# Cornelius
# David
# Derek
# Derek
# Dontence
# Demetrius
# Gary
# Jamal
# Kabel
# Kerry
# Mario
# Leroy
# Walte
# Loss: 1.09880810546875
# Alonzo
# Adelean
# Braylon
# Brayson
# Booker
# Claude
# James
# Johnny
# Micheal
# Sallie
# Andrew
# Avery
# Bruce
# Claudine
